# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 1-Задача

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
model=LinearRegression(normalize=True)
print(model)
def f(x):
    return x*np.sin(x)
x=np.array(np.linspace(0,10,30))
y=f(x)
X=x[:,np.newaxis]
model.fit(X,y)
model.coef_
model.intercept_
h=model.predict(X)
plt.scatter(X,y, color='black', marker='o')
plt.plot(X,h,color='blue' )
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)
X_train.shape
X_test.shape
from sklearn.metrics import mean_squared_error, r2_score
model=LinearRegression(normalize=True)
model.fit(X_train,y_train)
h_pred_test=model.predict(X_test)
mean_squared_error(y_test,h_pred_test)
h_pred_train=model.predict(X_train)
mean_squared_error(y_train,h_pred_train)
r2_score(y_test,h_pred_test)
r2_score(y_train,h_pred_train)
# Out:
# LinearRegression(normalize=True)
# 0.028026811890803693

# %%
plt.figure(2)
plt.scatter(X_test,y_test, color='red', marker='o')
plt.scatter(X_train,y_train, color='cyan', marker='o')
plt.plot(X,h,color='blue')

# %% [markdown]
# # 2-Задача

# %%
def f(x):
    return x*np.sin(x)
x = np.random.uniform(0, 10, size=30)
y = f(x)
X=x[:,np.newaxis]
model.fit(X,y)
model.coef_
model.intercept_
h=model.predict(X)
plt.plot(x,y,'ob')

# %% [markdown]
# # 3-Задача

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
sc_df = pd.read_csv('DeepLearning_v.1.0.csv')
sc_df.head()
# Out:
#                                                Field  2005  2006  2007  2008  \
# 0  Deep Learning + seq2seq (seq2seq, seqtoseq, se...     0     0     0     0
# 1  Deep Learning + convolutional (Convolutional, ...     0     0     0     0
# 2  Deep learning + generative model (generative a...     0     0     0     2
# 3  Deep learning + reinforcement (Reinforcement, RL)     0     0     0     0
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018   2019
# 0     1     0     1     0     0     2     3    11    35   104   27.0
# 1     0     2     2     1     2    28    97   399   903  2514  400.0
# 2     0     0     3     2     7    24    39    96   166   424    NaN
# 3     0     1     0     0     0     1     3     2     3    18    6.0

# %%
sc_df.keys()
# Out:
# Index(['Field', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019'],
#       dtype='object')

# %%
keys=np.array(sc_df.keys()) 
n=1
ka=np.array(keys.shape)
scnum=sc_df.loc[n,keys[1:ka[0]-0]]
y=np.array(scnum)
x=keys[1:ka[0]-0]
X=x[:,np.newaxis]
model.fit(X,y)
model.coef_
model.intercept_
h=model.predict(X)
plt.scatter(x,y, color='black', marker='o')
plt.plot(x,h,color = 'red')
